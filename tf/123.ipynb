# %%
import numpy as np

# %%
from PIL import Image
import keras_ocr

# Считывание изображений
images = [
    keras_ocr.tools.read(url) for url in [
        'https://festivalnauki.ru/upload/iblock/8b9/q3exkinhdb834t98so9l2pj9lbywrt78/fn_2023_dzen_1920x1080_region58.jpg'
    ]
]

# Преобразование в изображение Pillow для изменения размера
pil_images = [Image.fromarray(image) for image in images]

# Уменьшаем размер изображений с использованием Image.LANCZOS
resized_images = [img.resize((1024, 768), Image.LANCZOS) for img in pil_images]

# Прогон через пайплайн keras-ocr
prediction_groups = pipeline.recognize([np.array(img) for img in resized_images])

# Вывод результатов
for image, predictions in zip(resized_images, prediction_groups):
    keras_ocr.tools.drawAnnotations(image=np.array(image), predictions=predictions)
# Out:
# 2024-09-25 07:47:23.484149: W external/local_tsl/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 768.00MiB (rounded to 805306368)requested by op model_36/basenet.slice1.0/Conv2D
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-09-25 07:47:23.484249: I external/local_tsl/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-09-25 07:47:23.484292: I external/local_tsl/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 256, Chunks in use: 256. 64.0KiB allocated for chunks. 64.0KiB in use in bin. 35.2KiB client-requested in use in bin.
# ...

# %%
import tensorflow as tf

# %%
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for gpu in gpus:
        print("Найдено GPU:", gpu)
else:
    print("GPU не обнаружены")
# Out:
# Найдено GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# Найдено GPU: PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')
# Найдено GPU: PhysicalDevice(name='/physical_device:GPU:2', device_type='GPU')
# Найдено GPU: PhysicalDevice(name='/physical_device:GPU:3', device_type='GPU')
# Найдено GPU: PhysicalDevice(name='/physical_device:GPU:4', device_type='GPU')
